# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# when running on Kaggle
# df = pd.read_csv('/kaggle/input/80-cereals/cereal.csv')

# when running locally
df = pd.read_csv("cereal.csv")

df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.head(2)
# Out:
#                 name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 0          100% Bran   N    C        70        4    1     130   10.0    5.0
# 1  100% Natural Bran   Q    C       120        3    5      15    2.0    8.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 0       6     280        25      3     1.0  0.33  68.402973
# 1       8     135         0      3     1.0  1.00  33.983679

# %%
df.tail(3)
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
# mode = the most common item
df.fiber.mode()
# Out:
# 0    0.0
# Name: fiber, dtype: float64

# %%
df["calories"].mean()
# Out:
# 106.88311688311688

# %%
df.sugars.max()
# Out:
# 15

# %%
df.sugars.mean()
# Out:
# 6.922077922077922

# %%
df.sugars.std()
# Out:
# 4.444885392419359

# %%
df.carbo.mode()
# Out:
# 0    13.0
# 1    15.0
# Name: carbo, dtype: float64

# %%
df.carbo.mode().mean()
# Out:
# 14.0

# %% [markdown]
# ## Find average sugars "highly" rated cereals
#
# - top 25%

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# ## Average Sales of Leader vs. the rest

# %%
g_rating_average = df[df.mfr == "G"].rating.mean()
g_rating_average
# Out:
# 34.48585168181818

# %%
not_g_rating_average = df[df.mfr != "G"].rating.mean()
not_g_rating_average
# Out:
# 45.93764630909091

# %%
df.rating.quantile(.75)
# Out:
# 50.828392

# %%
sorted_by_rating = df.sort_values(by="rating", ascending=False)
top_rated_count = len(sorted_by_rating) // 4
top_quarter_rated = sorted_by_rating[0:top_rated_count+1]
top_quarter_rated
next_highest_rated_group = sorted_by_rating[top_rated_count:top_rated_count * 2]
next_highest_rated_group
# Out:
#                                       name mfr type  calories  protein  fat  \
# 57                          Quaker Oatmeal   Q    H       100        5    2
# 11                                Cheerios   G    C       110        6    2
# 74                              Wheat Chex   R    C       100        3    1
# 56                      Quaker Oat Squares   Q    C       100        4    1
# 8                                Bran Chex   R    C        90        2    1
# 21                                 Crispix   K    C       110        2    0
# 71                       Total Whole Grain   G    C       100        3    1
# 16                             Corn Flakes   K    C       100        2    0
# 34                      Great Grains Pecan   P    C       120        3    3
# 41                                    Life   Q    C       100        4    2
# 23                             Double Chex   R    C       100        2    0
# ...

# %%
sorted_by_rating.iloc[19] # get by single index
# Out:
# name        Quaker Oatmeal
# mfr                      Q
# type                     H
# calories               100
# protein                  5
# fat                      2
# sodium                   0
# fiber                  2.7
# carbo                 -1.0
# sugars                  -1
# potass                 110
# vitamins                 0
# shelf                    1
# weight                 1.0
# cups                  0.67
# rating           50.828392
# Name: 57, dtype: object

# %%
top_quarter_rated.sugars.mean()
# Out:
# 2.6

# %%
df[  df['mfr'] != 'G'   ].sugars.mean()
# Out:
# 6.509090909090909

# %%
grouped_by_mfr = df.groupby("mfr").sugars
grouped_by_mfr

# %%
df[ ["calories", "sugars" ] ]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
df[df.mfr == "G"]
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 7                   Basic 4   G    C       130        3    2     210    2.0
# 11                 Cheerios   G    C       110        6    2     290    2.0
# 12    Cinnamon Toast Crunch   G    C       120        1    3     210    0.0
# 13                 Clusters   G    C       110        3    2     140    2.0
# 14              Cocoa Puffs   G    C       110        1    1     180    0.0
# 18            Count Chocula   G    C       110        1    1     180    0.0
# 22   Crispy Wheat & Raisins   G    C       100        2    1     140    2.0
# 31           Golden Grahams   G    C       110        1    1     280    0.0
# 36       Honey Nut Cheerios   G    C       110        3    1     250    1.5
# 40                      Kix   G    C       110        2    1     260    0.0
# ...

# %%
df[df.mfr != "G"]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 15                               Corn Chex   R    C       110        2    0
# 16                             Corn Flakes   K    C       100        2    0
# ...

# %%
df[df.calories > 100]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 1                        100% Natural Bran   Q    C       120        3    5
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 11                                Cheerios   G    C       110        6    2
# 12                   Cinnamon Toast Crunch   G    C       120        1    3
# 13                                Clusters   G    C       110        3    2
# 14                             Cocoa Puffs   G    C       110        1    1
# 15                               Corn Chex   R    C       110        2    0
# ...
